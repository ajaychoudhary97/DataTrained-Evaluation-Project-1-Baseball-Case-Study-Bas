# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sn
#
# import warnings
# warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv("C:\\Users\Dell\\Desktop\\baseball.csv")

# %%
dataset.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
#     Loading The dataset

# %%
dataset.shape
# Out:
# (30, 17)

# %% [markdown]
#         We have 30 rows and 17 columns in dataset

# %%
    dataset.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
#    There is no null Values in dataset

# %%
dataset.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
#     These are the Columns Names

# %% [markdown]
# In the above dataset the target variable is ERA Column

# %%
dataset.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# These dataset mostly are integer types

# %% [markdown]
# #   Making DataFrame for the Nominal Data

# %%
dataset_visualization_nominal=dataset[['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']].copy()

# %%
dataset_visualization_nominal.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# #            Visualization of the data

# %%
import seaborn as sns

# %%
aj = sns.countplot(x="W", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["W"].value_counts())
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
#                Visualization The Data

# %%
aj = sns.countplot(x="R", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["R"].value_counts())
# Out:
# 696    2
# 689    2
# 703    1
# 669    1
# 644    1
# 720    1
# 647    1
# 713    1
# 650    1
# 655    1
# 656    1
# 724    1
# 661    1
# 729    1
# 667    1
# 737    1
# 573    1
# 613    1
# 683    1
# 748    1
# 622    1
# 751    1
# 626    1
# 694    1
# 697    1
# 891    1
# 764    1
# 640    1
# Name: R, dtype: int64

# %%
aj = sns.countplot(x="AB", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["AB"].value_counts())
# Out:
# 5485    2
# 5631    1
# 5467    1
# 5572    1
# 5509    1
# 5575    1
# 5640    1
# 5385    1
# 5567    1
# 5511    1
# 5649    1
# 5459    1
# 5480    1
# 5463    1
# 5529    1
# 5533    1
# 5565    1
# 5439    1
# 5600    1
# 5527    1
# 5605    1
# 5544    1
# 5417    1
# 5484    1
# 5420    1
# 5491    1
# 5428    1
# 5457    1
# 5571    1
# Name: AB, dtype: int64

# %%
aj = sns.countplot(x="H", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["H"].value_counts())
# Out:
# 1363    2
# 1341    1
# 1497    1
# 1405    1
# 1349    1
# 1351    1
# 1480    1
# 1479    1
# 1419    1
# 1420    1
# 1486    1
# 1361    1
# 1494    1
# 1495    1
# 1370    1
# 1462    1
# 1374    1
# 1378    1
# 1379    1
# 1381    1
# 1382    1
# 1383    1
# 1386    1
# 1515    1
# 1324    1
# 1331    1
# 1395    1
# 1397    1
# 1346    1
# Name: H, dtype: int64

# %%
aj = sns.countplot(x="2B", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["2B"].value_counts())
# Out:
# 272    3
# 288    2
# 278    2
# 289    2
# 277    2
# 260    2
# 274    2
# 251    1
# 236    1
# 294    1
# 295    1
# 262    1
# 265    1
# 257    1
# 263    1
# 292    1
# 303    1
# 243    1
# 308    1
# 246    1
# 279    1
# 300    1
# Name: 2B, dtype: int64

# %%
aj = sns.countplot(x="3B", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["3B"].value_counts())
# Out:
# 27    3
# 32    2
# 17    2
# 26    2
# 39    2
# 49    2
# 44    1
# 33    1
# 34    1
# 36    1
# 37    1
# 40    1
# 42    1
# 30    1
# 13    1
# 46    1
# 29    1
# 18    1
# 19    1
# 20    1
# 21    1
# 22    1
# 48    1
# Name: 3B, dtype: int64

# %%
    aj = sns.countplot(x="HR", data=dataset_visualization_nominal)
    print(dataset_visualization_nominal["HR"].value_counts())
# Out:
# 177    2
# 136    2
# 167    2
# 187    1
# 151    1
# 198    1
# 148    1
# 137    1
# 139    1
# 140    1
# 141    1
# 145    1
# 146    1
# 212    1
# 154    1
# 217    1
# 186    1
# 156    1
# 161    1
# 100    1
# 230    1
# 232    1
# 171    1
# 172    1
# 176    1
# 120    1
# 130    1
# Name: HR, dtype: int64

# %%
aj = sns.countplot(x="BB", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["BB"].value_counts())
# Out:
# 478    2
# 570    1
# 471    1
# 490    1
# 439    1
# 455    1
# 388    1
# 457    1
# 461    1
# 375    1
# 426    1
# 435    1
# 404    1
# 533    1
# 383    1
# 539    1
# 475    1
# 412    1
# 418    1
# 486    1
# 488    1
# 554    1
# 496    1
# 563    1
# 436    1
# 567    1
# 503    1
# 506    1
# 387    1
# Name: BB, dtype: int64

# %%
aj = sns.countplot(x="SO", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["SO"].value_counts())
# Out:
# 1150    2
# 1151    1
# 1119    1
# 1267    1
# 1283    1
# 1157    1
# 1159    1
# 1290    1
# 1227    1
# 973     1
# 1299    1
# 1231    1
# 1233    1
# 1107    1
# 1310    1
# 1312    1
# 1255    1
# 1322    1
# 1259    1
# 1264    1
# 1327    1
# 1392    1
# 1331    1
# 1258    1
# 1336    1
# 1274    1
# 1518    1
# 1148    1
# 1344    1
# Name: SO, dtype: int64

# %%
aj = sns.countplot(x="RA", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["RA"].value_counts())
# Out:
# 701    1
# 700    1
# 641    1
# 642    1
# 713    1
# 844    1
# 525    1
# 595    1
# 596    1
# 726    1
# 729    1
# 731    1
# 733    1
# 670    1
# 608    1
# 737    1
# 803    1
# 613    1
# 678    1
# 809    1
# 618    1
# 675    1
# 753    1
# 754    1
# 627    1
# 693    1
# 760    1
# 698    1
# 635    1
# 640    1
# Name: RA, dtype: int64

# %%
aj = sns.countplot(x="ER", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["ER"].value_counts())
# Out:
# 638    1
# 572    1
# 643    1
# 646    1
# 584    1
# 652    1
# 653    1
# 655    1
# 659    1
# 532    1
# 597    1
# 664    1
# 601    1
# 557    1
# 604    1
# 694    1
# 478    1
# 799    1
# 609    1
# 546    1
# 677    1
# 680    1
# 553    1
# 746    1
# 749    1
# 682    1
# 700    1
# 630    1
# 698    1
# 577    1
# Name: ER, dtype: int64

# %%
aj = sns.countplot(x="ERA", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["ERA"].value_counts())
# Out:
# 3.57    1
# 3.72    1
# 4.03    1
# 4.69    1
# 4.31    1
# 3.67    1
# 3.94    1
# 3.62    1
# 4.14    1
# 4.16    1
# 3.98    1
# 4.04    1
# 4.28    1
# 3.80    1
# 4.24    1
# 4.09    1
# 3.44    1
# 4.07    1
# 3.43    1
# 4.64    1
# 3.21    1
# 5.04    1
# 4.33    1
# 4.02    1
# 4.05    1
# 2.94    1
# 3.73    1
# 3.74    1
# 4.41    1
# 3.36    1
# Name: ERA, dtype: int64

# %%
aj = sns.countplot(x="CG", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["CG"].value_counts())
# Out:
# 1     7
# 7     4
# 2     4
# 6     3
# 5     3
# 3     3
# 0     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %%
aj = sns.countplot(x="SHO", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["SHO"].value_counts())
# Out:
# 12    7
# 10    5
# 13    3
# 21    2
# 15    2
# 9     2
# 8     2
# 7     2
# 4     2
# 18    1
# 14    1
# 6     1
# Name: SHO, dtype: int64

# %%
aj = sns.countplot(x="SV", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["SV"].value_counts())
# Out:
# 35    4
# 45    3
# 41    3
# 44    2
# 48    2
# 40    2
# 43    1
# 36    1
# 37    1
# 38    1
# 39    1
# 28    1
# 62    1
# 46    1
# 47    1
# 50    1
# 54    1
# 56    1
# 60    1
# 34    1
# Name: SV, dtype: int64

# %%
aj = sns.countplot(x="E", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["E"].value_counts())
# Out:
# 90     3
# 88     3
# 86     3
# 77     2
# 95     2
# 93     2
# 122    1
# 119    1
# 126    1
# 85     1
# 116    1
# 94     1
# 79     1
# 78     1
# 75     1
# 92     1
# 101    1
# 111    1
# 117    1
# 97     1
# 96     1
# Name: E, dtype: int64

# %% [markdown]
# #        Encoding The data

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in dataset.columns:
    if dataset[i].dtypes=="object":
        dataset[i]=enc.fit_transform(dataset[i].values.reshape(-1,1))

# %%
dataset
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# #      Describe The Dataset:

# %%
dataset.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(dataset.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #                       Correlation of the columns with the target columns:

# %%
dataset.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(dataset.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
#             Checking the columns which are positively and negative correlated with target columns:

# %%
plt.figure(figsize=(22,7))
dataset.corr()['ERA'].sort_values(ascending=False).drop(['ERA']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
dataset.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
#  Keeping +/0.5 as the range for skewness,here are the columns which does not lie within this range

# %% [markdown]
#    R - categorical
#    H - categorical
#   HR-  categorical
#   SHO- categorical
#   CG - categorical
#   SV  -categorical
#   E   - categorical
#   ERA - Target Variable

# %% [markdown]
# #       Outlier Chek:

# %%
dataset.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
#              Checking The outliers on the int and float type of columns.

# %%
dataset['H'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['E'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
#      Considering the outlier removal

# %%
dataset.shape
# Out:
# (30, 17)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(dataset))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
dataset_new_z=dataset[(z<3).all(axis=1)]
dataset_new_z
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
dataset_new_z.shape
# Out:
# (29, 17)

# %% [markdown]
#  percentage loss of data:

# %%
Data_loss=((30-29)/30)*100

# %%
Data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
#    Loss The data

# %% [markdown]
#   Separating the columns into features and Target:

# %%
features=dataset.drop("ERA",axis=1)
target=dataset["ERA"]

# %% [markdown]
# #      Scaling the data using Min-Max Scaler:

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=1)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is:- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.9995728376908769
# At random state 0,the testing accuracy is:- 0.9824484234523989
#
#
# At random state 1,the training accuracy is:- 0.9995728376908769
# At random state 1,the testing accuracy is:- 0.9824484234523989
#
#
# At random state 2,the training accuracy is:- 0.9995728376908769
# At random state 2,the testing accuracy is:- 0.9824484234523989
#
#
# At random state 3,the training accuracy is:- 0.9995728376908769
# At random state 3,the testing accuracy is:- 0.9824484234523989
#
#
# At random state 4,the training accuracy is:- 0.9995728376908769
# At random state 4,the testing accuracy is:- 0.9824484234523989
#
#
# At random state 5,the training accuracy is:- 0.9995728376908769
# At random state 5,the testing accuracy is:- 0.9824484234523989
#
#
# At random state 6,the training accuracy is:- 0.9995728376908769
# At random state 6,the testing accuracy is:- 0.9824484234523989
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.960431939863313

# %% [markdown]
# #        Corss-validation of the model:

# %%
     Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)


from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.6781647928320227 and accuracy score for training is -0.4427206897641125 and accuracy for the testing is 0.960431939863313
#
#
# At cross fold 3 the cv score is 0.9732036958710889 and accuracy score for training is -0.4427206897641125 and accuracy for the testing is 0.960431939863313
#
#
# At cross fold 4 the cv score is 0.9833245297303115 and accuracy score for training is -0.4427206897641125 and accuracy for the testing is 0.960431939863313
#
#
# At cross fold 5 the cv score is 0.9929186293117043 and accuracy score for training is -0.4427206897641125 and accuracy for the testing is 0.960431939863313
#
#
# At cross fold 6 the cv score is 0.9902843642797831 and accuracy score for training is -0.4427206897641125 and accuracy for the testing is 0.960431939863313
#
#
# At cross fold 7 the cv score is 0.9904313130779973 and accuracy score for training is -0.4427206897641125 and accuracy for the testing is 0.960431939863313
#
#
# ...

# %% [markdown]
#               Linear Regression

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual Score',fontsize=14)
plt.ylabel('Predicted Score',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
#          Blue line is Showing The Actual Dataset
#          red Line is Showing The Predication of the data

# %% [markdown]
# #           Regularization:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls = Lasso(alpha=1, random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.9728680428674114

# %% [markdown]
# #       Ensemble Technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "logo2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs =r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc =  rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 98.863419117647
# Cross Val Score: 83.35456698846542

# %% [markdown]
# #   We are getting model accuracy as 98.8 %
